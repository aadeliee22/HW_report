# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker
import matplotlib as mpl

# %% [markdown]
# # Matplotlib 5
#
# readable figure:
# - format: pdf, png>600dpi
# - font / color : r/g aviod; gray
# - legend / ticks / grid / inset (graph in graph)
# - No figure title...
# - ratio: $\Phi$ or 1:1?

# %%
mpl.rcParams.update({
    'font.family' : 'STIXGeneral',
    'mathtext.fontset' : 'stix',
    'font.size' : 9.0,
    'xtick.major.size' : 2 ,
    'xtick.minor.size' : 1.5 ,
    'xtick.major.width' : 0.75 ,
    'xtick.minor.width' : 0.75 ,
    'xtick.labelsize' : 8.0 ,
    'xtick.direction' : 'in' ,
    'xtick.top' : True ,
    'ytick.major.size' : 2 ,
    'ytick.minor.size' : 1.5 ,
    'ytick.major.width' : 0.75 ,
    'ytick.minor.width' : 0.75 ,
    'ytick.labelsize' : 8.0 ,
    'ytick.direction' : 'in' ,
    'xtick.major.pad' : 2 ,
    'xtick.minor.pad' : 2 ,
    'ytick.major.pad' : 2 ,
    'ytick.minor.pad' : 2 ,
    'ytick.right' : True ,
    'savefig.dpi' : 600 ,
    'axes.unicode_minus' : False ,
    'axes.linewidth' : 0.75 ,
    'lines.linewidth' : 1.0
})

# %%
width = 3.4 # 7.0 for twocol
height = width * 0.9

# %%
x = np.linspace(0,20)
y = x**2
fig = plt.figure(figsize = (width, height))
plt.plot(x,y, label=r'$y=x^2$')
plt.legend()

# %% [markdown]
# # Matplotlib 6
# OOP style

# %%
x = np.linspace(-100,100,2000)
y = np.sin(x)
ax = plt.gca() # get the current axes
ax.plot(x,y,label=r'$y = \sin(x)$')
ax.set_xlim(-6,6)
ax.set_xlabel('X-label')
ax.set_ylabel('Y-label')
# Out:
# Text(0, 0.5, 'Y-label')

# %% [markdown]
# # Matplotlib 7

# %%
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1.0)
ax.spines['left'].set_linewidth(1.0)
ax.spines['bottom'].set_color('r')
plt.tick_params(top=False, right=False)
x = np.linspace(-100,100,2000)
y = np.sin(x)
ax.plot(x,y)
ax.set_xlim(-6,6)
ax.set_xlabel('X label')
ax.set_ylabel('Y label')
# Out:
# Text(0, 0.5, 'Y label')

# %%
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1.0)
ax.spines['left'].set_linewidth(1.0)
ax.spines['bottom'].set_color('r')
plt.tick_params(axis='both', which='major', direction='inout', length=5, pad=5, top=False, right=False)
x = np.linspace(-100,100,2000)
y = np.sin(x)
ax.plot(x,y)
ax.set_xlim(-6,6)
ax.set_xlabel('X label', labelpad=10)
ax.set_ylabel('Y label')
# Out:
# Text(0, 0.5, 'Y label')

# %% [markdown]
# # Matplotlib 8

# %%
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.yaxis.set_major_locator(ticker.NullLocator())
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.tick_params(which='major', width=1, length=5)
ax.tick_params(which='minor', width=0.75, length=2.5)
ax.set_xlim(0, 5)
ax.set_ylim(0, 1)

ax.xaxis.set_major_locator(ticker.AutoLocator())
ax.xaxis.set_minor_locator(ticker.AutoMinorLocator())

# %%
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.yaxis.set_major_locator(ticker.NullLocator())
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.tick_params(which='major', width=1, length=5)
ax.tick_params(which='minor', width=0.75, length=2.5)
ax.set_xlim(0, 5)
ax.set_ylim(0, 1)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))

# %%
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.yaxis.set_major_locator(ticker.NullLocator())
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.tick_params(which='major', width=1, length=5)
ax.tick_params(which='minor', width=0.75, length=2.5)
ax.set_xlim(10**3, 10**10)
ax.set_xscale('log')

ax.xaxis.set_major_locator(ticker.LogLocator(base=100.0, numticks=15))
ax.xaxis.set_minor_locator(ticker.LogLocator(base=100.0, subs=(0.1,0.5)))
ax.xaxis.set_minor_formatter(ticker.NullFormatter())

# %%
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.yaxis.set_major_locator(ticker.NullLocator())
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.tick_params(which='major', width=1, length=5)
ax.tick_params(which='minor', width=0.75, length=2.5)
ax.set_xlim(0, 5)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1.00))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:g}"))
# = ax.xaxis.set_major_formatter(ticker.FormatStrFormatter("%d"))

# %%
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.yaxis.set_major_locator(ticker.NullLocator())
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.tick_params(which='major', width=1, length=5)
ax.tick_params(which='minor', width=0.75, length=2.5)
ax.set_xlim(0, 5)

ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.2f}"))
ax.xaxis.set_major_locator(ticker.MultipleLocator(1.00))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
# = ax.xaxis.set_major_formatter(ticker.FormatStrFormatter("%.2f"))

# %%
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.yaxis.set_major_locator(ticker.NullLocator())
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.tick_params(which='major', width=1, length=5)
ax.tick_params(which='minor', width=0.75, length=2.5)
ax.set_xlim(0, 5)

ax.xaxis.set_major_formatter(ticker.FuncFormatter(
    lambda x, pos: r"$%.1f\pi$" % x if x != 0 else "0"))
ax.xaxis.set_major_locator(ticker.MultipleLocator(1.00))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
